# %% [markdown]
# <a href="https://colab.research.google.com/github/sebasgaleano/ds-portfolio/blob/main/octubre_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# primera semana:
# profundizar
# - numpy
# - pandas
# - matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# dataset de prueba
df = pd.DataFrame({'edad': [21, 22 ,23 , 24, 25], 'ingresos': [1000, 2500, 3000, 4000, 5000], 'oficio': ['OP', 'DS', 'ADM', 'ML', 'DS']})

# explorar resultados
print(df.describe())
sns.scatterplot(data=df, x='edad', y='ingresos')
plt.show()
# Out:
#             edad     ingresos
# count   5.000000     5.000000
# mean   23.000000  3100.000000
# std     1.581139  1516.575089
# min    21.000000  1000.000000
# 25%    22.000000  2500.000000
# 50%    23.000000  3000.000000
# 75%    24.000000  4000.000000
# max    25.000000  5000.000000
